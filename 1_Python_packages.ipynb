# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashaswini944/Machine-Learning-and-DSA-practice/blob/main/1_Python_packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as ps
import pandas  as pd  # pandas allows us to organize data in a tabular form and to attach descriptive lables to the rows and columns
import scipy # its  python eco system
import statsmodels.api as sm # a package built on top of numpy, scipy , which integrates with pandas. SM provides very good summaries
import matplotlib.pyplot as plt # a 2D plotting library specialy designed for visualization of numpy computations
import seaborn as sns
sns.set() # is a python visualization library based on matpoltlib. It provides a high-leve; interface for frawing attractive statistical graphics
import sklearn # is one of the most widely used machine learning librabies .

# %% [markdown]
# simple Linear regression
#
# Import the relevant libraries
#
# Load the data

# %%
data = pd.read_csv('1.01. Simple linear regression.csv')
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %%
# Define the dependent and the independent variables
y = data['GPA']
x1 = data['SAT']

# %%
#explore the data
plt.scatter(x1,y)
plt.xlabel('SAT', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Tue, 18 Nov 2025   Prob (F-statistic):           7.20e-11
# Time:                        15:44:46   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# ...

# %%
plt.scatter(x1,y)
yhat = 0.0017*x1 + 0.275
fig = plt.plot(x1,yhat, lw=4, c= 'orange', label ='regression line')
plt.xlabel('SAT', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2875865406.py in <cell line: 0>()
#       1 #seaborn
# ----> 2 sns.set()
#
# NameError: name 'sns' is not defined
