# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashaswini944/Machine-Learning-and-DSA-practice/blob/main/1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Faster and easier data analysis with pandas
# pandas can import and export data from several formats(.csv, .xlsx,.json,.npz)
#best for analysing datasets contaning multiple types of information

#Numpy- best for numerical calculations

# %%
import pandas as pd

# %%
products = ['a','b','c','d']
products
type(products)
products_categories = pd.Series(products)
products_categories

type(products_categories)
# Out:
# pandas.core.series.Series

# %%
type(pd.Series(products))

daily_rates_dollars = pd.Series([40, 45, 60, 50])
daily_rates_dollars
# Out:
# 0    40
# 1    45
# 2    60
# 3    50
# dtype: int64

# %%
import numpy as np
import pandas as pd

array_a = np.array([10,20,30,40,50])
type(array_a)

series_a = pd.Series(array_a)
series_a.dtype
# Out:
# dtype('int64')

# %%
type(series_a)
# Out:
# pandas.core.series.Series

# %%
series_a.size
# Out:
# 5

# %%
product_categories  = pd.Series(['A','B','C','D'])
product_categories
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# dtype: object

# %%
product_categories.dtype
# Out:
# dtype('O')

# %%
product_categories.size
# Out:
# 4

# %%
type(product_categories.size)
# Out:
# int

# %%
product_categories.name
print(product_categories.name)
# Out:
# None

# %%
product_categories.name = "Product Categories"
product_categories
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: Product Categories, dtype: object

# %%
product_categories.name
# Out:
# 'Product Categories'

# %%
print(product_categories.name)
# Out:
# Product Categories
