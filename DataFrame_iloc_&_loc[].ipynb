# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashaswini944/Machine-Learning-and-DSA-practice/blob/main/DataFrame_iloc_%26_loc%5B%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **.iloc - i for integer , loc for location**
#
# Purely integer-location based indexing for selection by position

# %%
import pandas as pd

# %%
data = pd.read_csv('Lending-company.csv', index_col = 'StringID')
lending_data = data.copy()
lending_data.head()
# Out:
#           LoanID    Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_1       1  Product B         Female   Location 3  Region 2     17600.0
# LoanID_2       2  Product D         Female   Location 6  Region 6         NaN
# LoanID_3       3  Product B           Male   Location 8  Region 3     16600.0
# LoanID_4       4  Product A           Male  Location 26  Region 2     17600.0
# LoanID_5       5  Product B         Female  Location 34  Region 3     21250.0
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_1  04/07/2018     2200         45          365       3221       4166
# LoanID_2  02/01/2019     2200         45          365       3161       4096
# LoanID_3  08/12/2016     1000         45          365       2260       3205
# LoanID_4         NaN     2200         45          365       3141       4166
# LoanID_5  28/10/2017     2200         55          365       3570       4745
#
# ...

# %%
lending_data['Product']
# Out:
# StringID
# LoanID_1       Product B
# LoanID_2       Product D
# LoanID_3       Product B
# LoanID_4       Product A
# LoanID_5       Product B
#                  ...
# LoanID_1039    Product B
# LoanID_1040    Product A
# LoanID_1041    Product A
# LoanID_1042    Product B
# LoanID_1043    Product A
# Name: Product, Length: 1043, dtype: object

# %%
lending_data.iloc[1]
# Out:
# LoanID                     2
# Product            Product D
# CustomerGender        Female
# Location          Location 6
# Region              Region 6
# TotalPrice               NaN
# StartDate         02/01/2019
# Deposit                 2200
# DailyRate                 45
# TotalDaysYr              365
# AmtPaid36               3161
# AmtPaid60               4096
# AmtPaid360             16041
# LoanStatus            Active
# Name: LoanID_2, dtype: object

# %%
lending_data.iloc[1,3]
# Out:
# 'Location 6'

# %%
lending_data.iloc[1, :]
# Out:
# LoanID                     2
# Product            Product D
# CustomerGender        Female
# Location          Location 6
# Region              Region 6
# TotalPrice               NaN
# StartDate         02/01/2019
# Deposit                 2200
# DailyRate                 45
# TotalDaysYr              365
# AmtPaid36               3161
# AmtPaid60               4096
# AmtPaid360             16041
# LoanStatus            Active
# Name: LoanID_2, dtype: object

# %%
lending_data.iloc[:,3]
# Out:
# StringID
# LoanID_1        Location 3
# LoanID_2        Location 6
# LoanID_3        Location 8
# LoanID_4       Location 26
# LoanID_5       Location 34
#                   ...
# LoanID_1039    Location 73
# LoanID_1040    Location 82
# LoanID_1041    Location 11
# LoanID_1042    Location 26
# LoanID_1043    Location 94
# Name: Location, Length: 1043, dtype: object

# %%
type(lending_data.iloc[1,3])
# Out:
# str

# %%
type(lending_data.iloc[1,:])
# Out:
# pandas.core.series.Series

# %%
lending_data.iloc[[1,3], :]
# Out:
#           LoanID    Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_2       2  Product D         Female   Location 6  Region 6         NaN
# LoanID_4       4  Product A           Male  Location 26  Region 2     17600.0
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_2  02/01/2019     2200         45          365       3161       4096
# LoanID_4         NaN     2200         45          365       3141       4166
#
#           AmtPaid360 LoanStatus
# StringID
# LoanID_2       16041     Active
# LoanID_4       16321     Active

# %%
lending_data.iloc[: ,[1,3]]
# Out:
#                Product     Location
# StringID
# LoanID_1     Product B   Location 3
# LoanID_2     Product D   Location 6
# LoanID_3     Product B   Location 8
# LoanID_4     Product A  Location 26
# LoanID_5     Product B  Location 34
# ...                ...          ...
# LoanID_1039  Product B  Location 73
# LoanID_1040  Product A  Location 82
# LoanID_1041  Product A  Location 11
# LoanID_1042  Product B  Location 26
# LoanID_1043  Product A  Location 94
#
# [1043 rows x 2 columns]

# %% [markdown]
# loc[]

# %%
data = pd.read_csv('Lending-company.csv', index_col = 'StringID')
lending_data = data.copy()
lending_data.head()
# Out:
#           LoanID    Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_1       1  Product B         Female   Location 3  Region 2     17600.0
# LoanID_2       2  Product D         Female   Location 6  Region 6         NaN
# LoanID_3       3  Product B           Male   Location 8  Region 3     16600.0
# LoanID_4       4  Product A           Male  Location 26  Region 2     17600.0
# LoanID_5       5  Product B         Female  Location 34  Region 3     21250.0
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_1  04/07/2018     2200         45          365       3221       4166
# LoanID_2  02/01/2019     2200         45          365       3161       4096
# LoanID_3  08/12/2016     1000         45          365       2260       3205
# LoanID_4         NaN     2200         45          365       3141       4166
# LoanID_5  28/10/2017     2200         55          365       3570       4745
#
# ...

# %%
lending_data.loc['LoanID_3']
# Out:
# LoanID                     3
# Product            Product B
# CustomerGender          Male
# Location          Location 8
# Region              Region 3
# TotalPrice           16600.0
# StartDate         08/12/2016
# Deposit                 1000
# DailyRate                 45
# TotalDaysYr              365
# AmtPaid36               2260
# AmtPaid60               3205
# AmtPaid360             16340
# LoanStatus               NaN
# Name: LoanID_3, dtype: object

# %%
lending_data.loc['LoanID_3']
# Out:
# LoanID                     3
# Product            Product B
# CustomerGender          Male
# Location          Location 8
# Region              Region 3
# TotalPrice           16600.0
# StartDate         08/12/2016
# Deposit                 1000
# DailyRate                 45
# TotalDaysYr              365
# AmtPaid36               2260
# AmtPaid60               3205
# AmtPaid360             16340
# LoanStatus               NaN
# Name: LoanID_3, dtype: object

# %%
lending_data.loc['LoanID_3', :]
# Out:
# LoanID                     3
# Product            Product B
# CustomerGender          Male
# Location          Location 8
# Region              Region 3
# TotalPrice           16600.0
# StartDate         08/12/2016
# Deposit                 1000
# DailyRate                 45
# TotalDaysYr              365
# AmtPaid36               2260
# AmtPaid60               3205
# AmtPaid360             16340
# LoanStatus               NaN
# Name: LoanID_3, dtype: object

# %%
lending_data.loc['LoanID_3', 'Region']
# Out:
# 'Region 3'

# %%
lending_data.loc['Location']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-528463454.py in <cell line: 0>()
# ----> 1 lending_data.loc['Location']
#
# ...

# %%
lending_data.loc[:,'Location']
# Out:
# StringID
# LoanID_1        Location 3
# LoanID_2        Location 6
# LoanID_3        Location 8
# LoanID_4       Location 26
# LoanID_5       Location 34
#                   ...
# LoanID_1039    Location 73
# LoanID_1040    Location 82
# LoanID_1041    Location 11
# LoanID_1042    Location 26
# LoanID_1043    Location 94
# Name: Location, Length: 1043, dtype: object

# %%
lending_data.loc[:,'Locations']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Locations'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1618308071.py in <cell line: 0>()
# ----> 1 lending_data.loc[:,'Locations']
#
# ...

# %%
lending_data.shape
# Out:
# (1043, 14)

# %%
lending_data.iloc[1043,:]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1639450663.py in <cell line: 0>()
# ----> 1 lending_data.iloc[1043,:]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1688
#    1689     def _getitem_tuple(self, tup: tuple):
# -> 1690         tup = self._validate_tuple_indexer(tup)
#    1691         with suppress(IndexingError):
#    1692             return self._getitem_lowerdim(tup)
#
# ...

# %%
lending_data.iloc[:,14]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1267777778.py in <cell line: 0>()
# ----> 1 lending_data.iloc[:,14]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1688
#    1689     def _getitem_tuple(self, tup: tuple):
# -> 1690         tup = self._validate_tuple_indexer(tup)
#    1691         with suppress(IndexingError):
#    1692             return self._getitem_lowerdim(tup)
#
# ...

# %%
lending_data.iloc[:,13]
# Out:
# StringID
# LoanID_1                 Active
# LoanID_2                 Active
# LoanID_3                    NaN
# LoanID_4                 Active
# LoanID_5                 Active
#                      ...
# LoanID_1039    Finished Payment
# LoanID_1040    Finished Payment
# LoanID_1041    Finished Payment
# LoanID_1042    Finished Payment
# LoanID_1043    Finished Payment
# Name: LoanStatus, Length: 1043, dtype: object

# %%
lending_data.iloc[:,-1]
# Out:
# StringID
# LoanID_1                 Active
# LoanID_2                 Active
# LoanID_3                    NaN
# LoanID_4                 Active
# LoanID_5                 Active
#                      ...
# LoanID_1039    Finished Payment
# LoanID_1040    Finished Payment
# LoanID_1041    Finished Payment
# LoanID_1042    Finished Payment
# LoanID_1043    Finished Payment
# Name: LoanStatus, Length: 1043, dtype: object

# %%
lending_data['TotalPrice'].iloc[0]
# Out:
# np.float64(17600.0)

# %%
lending_data['TotalPrice'][0]
# Out:
# /tmp/ipython-input-1483234356.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lending_data['TotalPrice'][0]
# np.float64(17600.0)

# %%
lending_data['TotalPrice'][1]
# Out:
# /tmp/ipython-input-4135924244.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lending_data['TotalPrice'][1]
# np.float64(nan)

# %%
lending_data['TotalPrice'].loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2712880154.py in <cell line: 0>()
# ----> 1 lending_data['TotalPrice'].loc[1]
#
# ...

# %%
data = pd.read_csv('Lending-company.csv', index_col = 'StringID')
lending_data = data.copy()
lending_data.head()
# Out:
#           LoanID    Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_1       1  Product B         Female   Location 3  Region 2     17600.0
# LoanID_2       2  Product D         Female   Location 6  Region 6         NaN
# LoanID_3       3  Product B           Male   Location 8  Region 3     16600.0
# LoanID_4       4  Product A           Male  Location 26  Region 2     17600.0
# LoanID_5       5  Product B         Female  Location 34  Region 3     21250.0
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_1  04/07/2018     2200         45          365       3221       4166
# LoanID_2  02/01/2019     2200         45          365       3161       4096
# LoanID_3  08/12/2016     1000         45          365       2260       3205
# LoanID_4         NaN     2200         45          365       3141       4166
# LoanID_5  28/10/2017     2200         55          365       3570       4745
#
# ...

# %%
lending_data['TotalPrice'].iloc[0]
# Out:
# np.float64(17600.0)

# %%
lending_data['TotalPrice'].loc['LoanID_1']
# Out:
# np.float64(17600.0)

# %%
lending_data['TotalPrice'][0]
# Out:
# /tmp/ipython-input-1483234356.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lending_data['TotalPrice'][0]
# np.float64(17600.0)

# %%
lending_data['TotalPrice'][1]
# Out:
# /tmp/ipython-input-4135924244.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lending_data['TotalPrice'][1]
# np.float64(nan)

# %%
lending_data['TotalPrice']['LoanID_1']
# Out:
# np.float64(17600.0)

# %%
lending_data.ilon[0][5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2909823660.py in <cell line: 0>()
# ----> 1 lending_data.ilon[0][5]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'ilon'

# %%
lending_data.iloc[[0,5]]
# Out:
#           LoanID    Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_1       1  Product B         Female   Location 3  Region 2     17600.0
# LoanID_6       6  Product A           Male  Location 34  Region 1         NaN
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_1  04/07/2018     2200         45          365       3221       4166
# LoanID_6  19/04/2019     2200         45          365       3301       4066
#
#           AmtPaid360 LoanStatus
# StringID
# LoanID_1       14621     Active
# LoanID_6       15141     Active

# %%
lending_data['TotalPrice']['LoanID_1']
# Out:
# np.float64(17600.0)

# %%
lending_data.loc['LoanID_1', 'TotalPrice']
# Out:
# np.float64(17600.0)

# %%
lending_data.loc[['LoanID_1', 'LoanID_6']]
# Out:
#           LoanID    Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_1       1  Product B         Female   Location 3  Region 2     17600.0
# LoanID_6       6  Product A           Male  Location 34  Region 1         NaN
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_1  04/07/2018     2200         45          365       3221       4166
# LoanID_6  19/04/2019     2200         45          365       3301       4066
#
#           AmtPaid360 LoanStatus
# StringID
# LoanID_1       14621     Active
# LoanID_6       15141     Active

# %%
lending_data.loc[['LoanID_1', 'LoanID_6'], :]
# Out:
#           LoanID    Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_1       1  Product B         Female   Location 3  Region 2     17600.0
# LoanID_6       6  Product A           Male  Location 34  Region 1         NaN
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_1  04/07/2018     2200         45          365       3221       4166
# LoanID_6  19/04/2019     2200         45          365       3301       4066
#
#           AmtPaid360 LoanStatus
# StringID
# LoanID_1       14621     Active
# LoanID_6       15141     Active

# %%
lending_data['TotalPrice'].iloc[[0,5]]
# Out:
# StringID
# LoanID_1    17600.0
# LoanID_6        NaN
# Name: TotalPrice, dtype: float64

# %%
lending_data.loc[:, 'TotalPrice'].iloc[[0,5]]
# Out:
# StringID
# LoanID_1    17600.0
# LoanID_6        NaN
# Name: TotalPrice, dtype: float64
